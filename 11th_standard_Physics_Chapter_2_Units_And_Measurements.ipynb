# %% [markdown]
# <a href="https://colab.research.google.com/github/ruforavishnu/Project_Simulations/blob/main/11th_standard_Physics_Chapter_2_Units_And_Measurements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 2 - Units and Measurements

# %% [markdown]
# Units and Measurements – Error Analysis Simulator

# %%
pip install numpy matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  Simulate Measurement Errors

# %%
true_value = 100

num_measurements = 1000
errors = np.random.normal(loc=0, scale=2, size=num_measurements)

measured_values = true_value + errors

# %% [markdown]
# Visualize Error Distribution

# %%
plt.figure(figsize=(10,5))
plt.hist(errors, bins=30, color='skyblue', edgecolor='black', alpha=0.7)

plt.xlabel('Measurement Error')
plt.ylabel('Frequency')
plt.title('Distribution of Measurement Errors')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
