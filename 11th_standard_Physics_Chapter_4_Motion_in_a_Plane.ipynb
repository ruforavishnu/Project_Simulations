# %% [markdown]
# <a href="https://colab.research.google.com/github/ruforavishnu/Project_Simulations/blob/main/11th_standard_Physics_Chapter_4_Motion_in_a_Plane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 4 - Motion in a Plane

# %% [markdown]
# ### Project : Newton’s Laws of Motion - Simulating a Moving Car with Forces

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %%
m = 1000
F = 500
u = 0
t_max = 10
dt = 0.1

# %%
a = F/m

t = np.arange(0, t_max, dt)

v = u+ a*t
s = u*t + 0.5*a*t**2

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.set_xlim(0, max(s)+5 )
ax.set_ylim(-1,1)
ax.set_xlabel('Distance (m)')
ax.set_title('Car motion under Applied Force')

car, = ax.plot([s[0]], [0], 'bs', markersize=15)

def update(frame):
  car.set_data([s[frame]], [0])
  return car,


ani = animation.FuncAnimation(fig, update, frames=len(t), interval=100, blit=True)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
